# %% [markdown]
# # Linear Regression

# %% [markdown]
# Let's fabricate some data that shows a roughly linear relationship between page speed and amount purchased:

# %%
# %matplotlib inline
import numpy as np
from pylab import *

pageSpeeds = np.random.normal(3.0, 1.0, 1000)
purchaseAmount = 100 - (pageSpeeds + np.random.normal(0, 0.1, 1000)) * 3

scatter(pageSpeeds, purchaseAmount)

# %% [markdown]
# As we only have two features, we can keep it simple and just use scipy.state.linregress:

# %%
from scipy import stats

slope, intercept, r_value, p_value, std_err = stats.linregress(pageSpeeds, purchaseAmount)

# %% [markdown]
# Not surprisngly, our R-squared value shows a really good fit:

# %%
r_value ** 2
# Out:
# np.float64(0.9894360322875022)

# %% [markdown]
# Let's use the slope and intercept we got from the regression to plot predicted values vs. observed:

# %%
import matplotlib.pyplot as plt

def predict(x):
    return slope * x + intercept

fitLine = predict(pageSpeeds)

plt.scatter(pageSpeeds, purchaseAmount)
plt.plot(pageSpeeds, fitLine, c='r')
plt.show()

# %% [markdown]
# ## Activity

# %% [markdown]
# Try increasing the random variation in the test data, and see what effect it has on the r-squared error value.

# %%
pageSpeeds2 = np.random.normal(3.0, 1.0, 1000)
purchaseAmount2 = 100 - (pageSpeeds2 + np.random.normal(0, 0.3, 1000)) * 3

scatter(pageSpeeds2, purchaseAmount2)

# %%
slope2, intercept2, r_value2, p_value2, std_err2 = stats.linregress(pageSpeeds2, purchaseAmount2)

# %%
# new r-squared value
r_value2 ** 2
# Out:
# np.float64(0.9155953688277197)

# %%
def predict(x):
    return slope2 * x + intercept2

fitLine2 = predict(pageSpeeds2)

plt.scatter(pageSpeeds2, purchaseAmount2)
plt.plot(pageSpeeds2, fitLine2, c='r')
plt.show()
